# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
import  matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3082, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.169004
# Nearest to in: haze, lintel, utilizing, norris, comparably, popov, literals, jolley,
# Nearest to a: docks, snapshots, neural, ferret, basotho, aleutian, sieges, sound,
# Nearest to that: princip, uppsala, maids, sexism, milled, perlite, intestine, delays,
# Nearest to also: wizards, tanoana, complementary, archbishops, destroys, wronged, anni, mithraic,
# Nearest to s: occultist, spins, membranes, pyrrhus, abimelech, fourteen, green, unfalsifiable,
# Nearest to not: tis, fc, scuttled, fredericksburg, complying, ceasefire, toned, annals,
# Nearest to will: rhotic, kali, calls, brandeis, sleeps, croesus, fiscal, wootz,
# Nearest to if: karim, terraced, enunciated, trolleybus, libi, housemates, alam, ayahuasca,
# Nearest to he: shortly, generalitat, superior, podkopayeva, property, hunan, rdenas, subcode,
# Nearest to all: arbroath, wynette, forman, cloth, coldest, pseudocode, bystanders, sopra,
# Nearest to when: aide, ves, dominicans, ideological, castrato, conjugal, shuffled, adopted,
# Nearest to be: khoi, hydrated, strings, etudes, consecutive, shallower, mcdonnell, orion,
# Nearest to an: inventories, kriegsmarine, feininger, fdp, handed, loon, rewriting, seo,
# Nearest to american: pretends, decrypt, enactments, organelle, migne, holger, hort, triads,
# Nearest to such: bot, hereditary, danubian, validate, rst, pople, rufinus, somaliland,
# Nearest to their: mises, jerky, isothermal, manure, chalcedon, privilege, amicable, christoph,
# Average loss at step 2000: 4.365219
# Average loss at step 4000: 3.863176
# Average loss at step 6000: 3.787796
# Average loss at step 8000: 3.685905
# Average loss at step 10000: 3.609309
# Nearest to in: from, on, of, with, at, for, during, ferroelectric,
# Nearest to a: the, aleutian, this, theocracy, basotho, cytokinesis, manganese, hannity,
# Nearest to that: which, gotthold, what, princip, it, theodor, this, grammars,
# Nearest to also: often, it, homotopy, he, which, wronged, stride, santorini,
# Nearest to s: his, celebrates, and, pediatrician, equinox, adder, or, the,
# Nearest to not: it, never, they, geezer, you, scuttled, turbocharger, usually,
# Nearest to will: rhotic, kali, judgments, shenouda, would, undefined, cardinality, utilising,
# Nearest to if: karim, wroc, libi, terraced, enunciated, apeiron, accomplishes, trolleybus,
# Nearest to he: it, they, she, who, never, kathmandu, ltd, there,
# Nearest to all: record, arbroath, juntas, favouring, coldest, fed, drabble, dragster,
# Nearest to when: zuma, confuses, ves, deteriorate, conjugal, cursed, shuffled, americas,
# Nearest to be: have, is, was, unleash, were, being, nomen, are,
# Nearest to an: inventories, kriegsmarine, cowpox, the, poisoning, invades, pegged, eclipsed,
# Nearest to american: decrypt, french, borrelly, cosmic, continental, ansbach, burghs, cfaf,
# Nearest to such: well, religious, known, validate, cartan, merge, hin, flammable,
# Nearest to their: his, its, mises, riel, compartment, swamps, her, the,
# Average loss at step 12000: 3.602584
# Average loss at step 14000: 3.571591
# Average loss at step 16000: 3.405147
# Average loss at step 18000: 3.458421
# Average loss at step 20000: 3.540146
# Nearest to in: on, from, at, with, during, dien, by, between,
# Nearest to a: the, any, basotho, this, unintended, ploy, every, tinged,
# Nearest to that: which, but, however, this, princip, when, because, intestine,
# Nearest to also: often, which, not, now, homotopy, generally, it, venezuela,
# Nearest to s: participated, pediatrician, backfire, cyclopedia, lunar, essen, thistle, buprenorphine,
# Nearest to not: never, they, also, it, you, to, geezer, still,
# Nearest to will: would, can, could, may, cannot, judgments, rhotic, to,
# Nearest to if: when, taker, apeiron, but, says, is, wroc, philharmonic,
# Nearest to he: it, they, she, who, there, never, ltd, kondratiev,
# Nearest to all: many, record, these, each, any, carson, guelleh, furs,
# Nearest to when: if, while, was, under, where, had, bihar, hawley,
# Nearest to be: have, been, being, was, were, is, by, become,
# Nearest to an: the, kriegsmarine, pegged, digraph, inventories, bihar, feininger, dealing,
# Nearest to american: french, german, decrypt, acted, spaniard, british, rh, continental,
# Nearest to such: well, religious, known, these, validate, connery, continuation, cartan,
# Nearest to their: his, its, the, her, some, swamps, riel, dhahran,
# Average loss at step 22000: 3.501135
# Average loss at step 24000: 3.486815
# Average loss at step 26000: 3.482285
# Average loss at step 28000: 3.477175
# Average loss at step 30000: 3.503337
# Nearest to in: during, at, until, of, on, from, and, by,
# Nearest to a: walnut, any, austrasia, the, eftpos, aleutian, no, transcendence,
# Nearest to that: which, what, this, princip, however, because, havas, plumes,
# Nearest to also: often, it, now, which, venezuela, usually, sometimes, who,
# Nearest to s: pediatrician, his, thrush, buprenorphine, br, overtraining, salford, pett,
# Nearest to not: never, still, they, it, you, better, there, to,
# Nearest to will: would, can, may, could, cannot, must, should, to,
# Nearest to if: when, but, though, although, says, accomplishes, wroc, since,
# Nearest to he: she, it, they, who, there, never, but, giambattista,
# Nearest to all: some, these, many, record, any, each, furs, embarrassed,
# Nearest to when: if, after, while, where, under, but, was, before,
# Nearest to be: been, have, were, being, is, tribunals, exist, was,
# Nearest to an: kriegsmarine, bihar, suebi, inventories, arecibo, pegged, decorated, walden,
# Nearest to american: british, english, french, german, decrypt, citizenry, continental, thrust,
# Nearest to such: well, known, these, religious, many, cil, connery, sugarcane,
# Nearest to their: his, its, her, the, these, some, swamps, riel,
# Average loss at step 32000: 3.499411
# Average loss at step 34000: 3.496072
# Average loss at step 36000: 3.455865
# Average loss at step 38000: 3.307035
# Average loss at step 40000: 3.432348
# Nearest to in: at, during, of, for, from, is, jolley, and,
# Nearest to a: the, any, or, another, posture, biota, no, astigmatism,
# Nearest to that: which, what, this, however, it, but, enhancers, who,
# Nearest to also: often, which, now, usually, who, generally, increasingly, still,
# Nearest to s: his, pediatrician, bogdanovich, cdots, rover, and, overtraining, narcolepsy,
# Nearest to not: never, still, they, it, better, geezer, usually, representationalism,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to if: when, for, where, peloponnesus, lineal, is, ibo, hoffer,
# Nearest to he: she, it, they, who, there, ltd, i, giambattista,
# Nearest to all: both, record, these, furs, many, synthesizer, any, juntas,
# Nearest to when: if, before, after, while, where, but, for, during,
# Nearest to be: been, have, were, was, being, is, establish, are,
# Nearest to an: kriegsmarine, inventories, permission, dealing, lamm, magistrates, walden, mcnally,
# Nearest to american: british, french, german, kentucky, cfaf, european, disagreements, spaniard,
# Nearest to such: well, known, these, cil, many, religious, including, schwerin,
# Nearest to their: its, his, her, the, your, some, these, riel,
# Average loss at step 42000: 3.433214
# Average loss at step 44000: 3.451261
# Average loss at step 46000: 3.445167
# Average loss at step 48000: 3.352881
# Average loss at step 50000: 3.385524
# Nearest to in: during, within, on, from, since, of, surrey, estonians,
# Nearest to a: the, another, any, no, subsist, posture, fungus, biota,
# Nearest to that: which, however, what, this, histoire, where, madden, because,
# Nearest to also: often, which, now, sometimes, generally, who, then, usually,
# Nearest to s: pediatrician, and, imaginable, cdots, neglect, thrush, bogdanovich, kitchens,
# Nearest to not: never, usually, they, geezer, it, still, better, you,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to if: when, where, although, before, though, lineal, unless, but,
# Nearest to he: she, it, they, who, there, never, giambattista, i,
# Nearest to all: both, many, each, any, some, these, languedoc, furs,
# Nearest to when: if, while, where, after, before, during, however, until,
# Nearest to be: have, been, being, was, were, become, remain, establish,
# Nearest to an: inventories, permission, kriegsmarine, lamm, digraph, the, dealing, feininger,
# Nearest to american: european, french, british, english, turkish, cfaf, spaniard, decrypt,
# Nearest to such: well, known, these, many, sugarcane, cil, connery, tectonic,
# Nearest to their: its, his, her, the, your, some, both, riel,
# Average loss at step 52000: 3.434869
# Average loss at step 54000: 3.424161
# Average loss at step 56000: 3.439952
# Average loss at step 58000: 3.394817
# Average loss at step 60000: 3.395006
# Nearest to in: within, of, during, since, at, from, on, into,
# Nearest to a: the, any, another, every, ploy, basotho, prepared, subsist,
# Nearest to that: which, what, however, it, this, generally, madden, where,
# Nearest to also: often, now, generally, still, sometimes, currently, which, usually,
# Nearest to s: pediatrician, telecoms, opel, overtraining, thrush, imaginable, kitchens, enoch,
# Nearest to not: never, still, you, usually, they, now, better, generally,
# Nearest to will: would, could, may, can, must, should, cannot, might,
# Nearest to if: when, where, though, before, although, lineal, unmixed, saying,
# Nearest to he: she, it, they, who, there, i, never, we,
# Nearest to all: many, any, each, some, both, these, those, apologized,
# Nearest to when: if, before, although, while, after, where, because, though,
# Nearest to be: been, is, become, was, were, have, are, remain,
# Nearest to an: inventories, kriegsmarine, permission, digraph, lamm, barristers, magistrates, invades,
# Nearest to american: british, european, german, english, decrypt, african, cfaf, turkish,
# Nearest to such: well, known, these, many, sugarcane, religious, cil, schwerin,
# Nearest to their: its, his, her, your, our, the, riel, whose,
# Average loss at step 62000: 3.241909
# Average loss at step 64000: 3.249799
# Average loss at step 66000: 3.400576
# Average loss at step 68000: 3.395094
# Average loss at step 70000: 3.357282
# Nearest to in: within, during, on, among, at, from, until, beyond,
# Nearest to a: the, another, basotho, posture, biota, this, any, subsist,
# Nearest to that: which, however, what, but, this, generally, also, madden,
# Nearest to also: often, now, still, which, sometimes, generally, not, that,
# Nearest to s: pediatrician, cdots, overtraining, thrush, isbn, bogdanovich, whose, imaginable,
# Nearest to not: never, still, now, also, they, usually, generally, rarely,
# Nearest to will: would, may, could, can, must, should, cannot, might,
# Nearest to if: when, where, though, before, while, since, unmixed, saying,
# Nearest to he: she, it, they, who, there, never, eventually, we,
# Nearest to all: many, some, any, each, every, most, those, both,
# Nearest to when: if, while, before, where, however, because, after, although,
# Nearest to be: been, were, become, have, is, are, being, translocation,
# Nearest to an: inventories, kriegsmarine, permission, pegged, feininger, mcnally, digraph, the,
# Nearest to american: british, decrypt, cfaf, european, english, korean, tallinn, indian,
# Nearest to such: these, well, known, many, including, regarded, sugarcane, defined,
# Nearest to their: its, his, her, the, your, riel, some, our,
# Average loss at step 72000: 3.370202
# Average loss at step 74000: 3.346703
# Average loss at step 76000: 3.310634
# Average loss at step 78000: 3.351057
# Average loss at step 80000: 3.372939
# Nearest to in: on, during, within, at, under, since, until, from,
# Nearest to a: another, posture, every, arbitrator, too, the, biota, dur,
# Nearest to that: which, however, where, princip, madden, plumes, but, showtime,
# Nearest to also: still, often, now, which, sometimes, never, actually, frequently,
# Nearest to s: pediatrician, isbn, adder, imaginable, gonz, haifa, juventus, neil,
# Nearest to not: never, still, they, generally, rarely, it, really, you,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to if: when, since, though, where, before, although, saying, unmixed,
# Nearest to he: she, it, they, there, who, we, iommi, never,
# Nearest to all: any, both, every, many, each, some, those, most,
# Nearest to when: before, after, if, during, while, because, though, egyptologists,
# Nearest to be: been, have, become, being, is, remain, translocation, were,
# Nearest to an: inventories, permission, kriegsmarine, lamm, sustained, mcnally, paraphyletic, digraph,
# Nearest to american: british, international, english, european, cfaf, african, german, australian,
# Nearest to such: well, these, known, mindset, regarded, petty, schwerin, defined,
# Nearest to their: its, his, her, your, our, whose, both, riel,
# Average loss at step 82000: 3.404183
# Average loss at step 84000: 3.407994
# Average loss at step 86000: 3.387548
# Average loss at step 88000: 3.349722
# Average loss at step 90000: 3.364138
# Nearest to in: during, within, of, under, and, until, among, around,
# Nearest to a: another, every, the, subsist, any, posture, lacrosse, aleutian,
# Nearest to that: however, which, generally, what, but, madden, princip, framed,
# Nearest to also: still, often, which, now, actually, sometimes, never, generally,
# Nearest to s: pediatrician, his, whose, isbn, imaginable, thrush, max, haifa,
# Nearest to not: never, still, now, actually, generally, they, there, better,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to if: when, where, since, though, before, although, unmixed, saying,
# Nearest to he: she, it, they, there, who, ltd, giambattista, later,
# Nearest to all: many, both, some, several, every, any, each, most,
# Nearest to when: if, before, where, after, while, although, egyptologists, without,
# Nearest to be: been, become, have, is, was, being, easily, establish,
# Nearest to an: kriegsmarine, permission, inventories, digraph, another, lamm, pegged, barristers,
# Nearest to american: british, english, european, french, african, korean, international, decrypt,
# Nearest to such: well, known, these, follows, defined, cil, regarded, seen,
# Nearest to their: its, his, her, your, our, whose, both, my,
# Average loss at step 92000: 3.399498
# Average loss at step 94000: 3.254957
# Average loss at step 96000: 3.356501
# Average loss at step 98000: 3.237936
# Average loss at step 100000: 3.355925
# Nearest to in: during, within, on, until, from, at, beyond, of,
# Nearest to a: another, the, any, manganese, ploy, biota, bis, munk,
# Nearest to that: which, however, what, princip, but, who, treehouse, madden,
# Nearest to also: actually, still, now, often, never, sometimes, usually, generally,
# Nearest to s: whose, his, pediatrician, thrush, anemometers, yersinia, isbn, the,
# Nearest to not: never, still, they, t, generally, now, mostly, nor,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to if: when, where, though, before, while, since, because, unmixed,
# Nearest to he: she, it, they, there, who, we, never, giambattista,
# Nearest to all: many, every, some, several, these, any, both, various,
# Nearest to when: if, before, while, where, although, after, though, because,
# Nearest to be: been, become, is, have, being, are, translocation, remain,
# Nearest to an: permission, kriegsmarine, inventories, another, magistrates, lined, dixit, eclipse,
# Nearest to american: canadian, british, french, german, italian, english, australian, decrypt,
# Nearest to such: well, known, these, defined, many, regarded, including, separate,
# Nearest to their: its, his, her, your, our, whose, the, some,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# #### Bag of Words

# %%
 data_index = 0

# skip-gram dataset generation function
def generate_cbow_batch(batch_size, skip_window):
  """
  
  Parameters
  ----------
  skips_window: int : How many words to consider left and right.
  
  """
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)

  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

# %%
# CBOW model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.262934
# Nearest to when: phenomenal, appendages, brokered, comedian, debunking, anarchist, messianic, repugnant,
# Nearest to american: sullivan, algal, kiang, jeopardy, subgroup, laing, brochure, admissible,
# Nearest to more: albums, supple, descendents, mips, compounded, regensburg, philibert, chaired,
# Nearest to which: lomond, diva, cricket, omnipotence, plumage, bassoon, macon, popped,
# Nearest to than: earthbound, objected, multicultural, pluck, orthographies, dump, prog, nancy,
# Nearest to zero: paralyzed, boulder, keralite, boring, charpentier, loyalties, alda, speculative,
# Nearest to so: engl, daddy, psychometric, fresco, agile, straddling, telepathic, belladonna,
# Nearest to had: rented, kitchener, peroxides, abrogated, introns, wheaton, knossos, unusually,
# Nearest to while: sub, wales, druidism, diagnosing, incited, things, referring, fireballs,
# Nearest to of: mooring, matrix, sizeable, dominus, crested, hodges, soldier, weighing,
# Nearest to used: contends, propyl, hrothgar, alessandro, journalism, arise, whichever, alluding,
# Nearest to some: transmits, plosive, firewalls, glycine, apparently, rejoice, dune, cohorts,
# Nearest to five: dodger, damnation, sacrifice, corpses, ebro, which, sumatra, tosses,
# Nearest to other: owner, x, neuter, gateways, defaults, carrier, recipe, investigator,
# Nearest to known: faked, exclusivity, imo, cie, dialects, murdered, cartographers, replication,
# Nearest to into: gothenburg, graces, proverbs, fair, marion, harvester, corrosive, cdr,
# Average loss at step 2000: 4.144095
# Average loss at step 4000: 3.558226
# Average loss at step 6000: 3.387853
# Average loss at step 8000: 3.246144
# Average loss at step 10000: 3.179240
# Nearest to when: andrei, vcrs, hospitable, repugnant, before, turpin, technik, braun,
# Nearest to american: british, french, farragut, russian, istanbul, athenian, kernels, african,
# Nearest to more: less, allotment, albums, most, coeur, planting, centrality, preview,
# Nearest to which: that, who, this, also, it, django, colder, fanfic,
# Nearest to than: chileans, or, mmorpgs, clue, prog, migratory, endomorphism, offsets,
# Nearest to zero: four, five, seven, six, eight, three, nine, two,
# Nearest to so: keefe, scratch, apprehend, psychometric, immersive, deadly, scrupulously, courted,
# Nearest to had: has, have, was, were, fueled, hep, ceremonially, having,
# Nearest to while: climbed, gyula, luminiferous, achieves, styria, fireballs, diagnosing, will,
# Nearest to of: chat, abortive, almagest, pathogenic, possessor, midrashim, during, weighing,
# Nearest to used: known, described, referred, korchnoi, found, deteriorate, earthen, habitable,
# Nearest to some: many, these, most, galveston, everyday, all, undermines, several,
# Nearest to five: four, six, eight, three, seven, two, nine, zero,
# Nearest to other: many, owner, botc, some, paired, microscopy, flynt, comedienne,
# Nearest to known: such, used, cartographers, erebus, referred, aeon, eccles, emigr,
# Nearest to into: gothenburg, charlatans, allied, vertebra, feature, from, graces, journalists,
# Average loss at step 12000: 3.206796
# Average loss at step 14000: 3.154735
# Average loss at step 16000: 3.174135
# Average loss at step 18000: 3.123462
# Average loss at step 20000: 2.994513
# Nearest to when: if, before, for, after, while, since, where, vcrs,
# Nearest to american: french, english, irish, african, german, beehive, british, energies,
# Nearest to more: less, most, allotment, very, greater, other, albums, conan,
# Nearest to which: this, that, also, who, often, but, there, luisa,
# Nearest to than: or, chileans, mmorpgs, clue, succulent, jeeps, offsets, threaded,
# Nearest to zero: seven, six, five, nine, four, eight, three, thirds,
# Nearest to so: envelope, keefe, tsiolkovsky, liturgical, sparrow, scrupulously, relied, toynbee,
# Nearest to had: has, have, was, became, were, having, wanted, dives,
# Nearest to while: but, krueger, when, after, achieves, steered, and, gravitational,
# Nearest to of: for, lofty, halo, hooked, zhang, chat, in, alarm,
# Nearest to used: known, found, described, referred, available, required, korchnoi, built,
# Nearest to some: many, these, any, several, most, tutankhamun, tsuburaya, their,
# Nearest to five: seven, six, four, eight, three, nine, zero, two,
# Nearest to other: various, different, intergalactic, newsstand, comedienne, more, obsidian, severly,
# Nearest to known: used, such, referred, regarded, described, defined, refraining, well,
# Nearest to into: through, gothenburg, from, vertebra, charlatans, feature, across, graces,
# Average loss at step 22000: 3.067432
# Average loss at step 24000: 3.039320
# Average loss at step 26000: 3.000459
# Average loss at step 28000: 3.028148
# Average loss at step 30000: 3.007814
# Nearest to when: if, before, after, while, where, during, grande, although,
# Nearest to american: french, irish, german, african, british, energies, english, beehive,
# Nearest to more: less, most, very, too, other, rather, fewer, allotment,
# Nearest to which: that, this, also, who, but, nano, what, it,
# Nearest to than: or, but, mmorpgs, much, chileans, jannaeus, resembling, lift,
# Nearest to zero: five, four, eight, seven, nine, six, three, u,
# Nearest to so: if, before, keefe, insecure, impacting, argued, gatherings, increasingly,
# Nearest to had: has, have, was, having, were, codebase, became, yet,
# Nearest to while: when, before, contaminants, after, krueger, although, however, though,
# Nearest to of: zhang, in, like, including, halo, lofty, suffocation, lycos,
# Nearest to used: referred, known, described, found, held, called, considered, available,
# Nearest to some: many, several, these, any, most, all, augustin, those,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to other: various, different, more, comedienne, several, many, karamanlis, intergalactic,
# Nearest to known: used, such, defined, regarded, referred, well, called, described,
# Nearest to into: through, from, across, gothenburg, protectorate, around, feature, under,
# Average loss at step 32000: 2.826027
# Average loss at step 34000: 2.955846
# Average loss at step 36000: 2.949375
# Average loss at step 38000: 2.944009
# Average loss at step 40000: 2.927521
# Nearest to when: before, after, if, while, grande, during, because, since,
# Nearest to american: french, british, irish, african, australian, italian, beehive, german,
# Nearest to more: less, most, very, rather, fewer, planting, relatively, coeur,
# Nearest to which: this, that, also, what, who, often, usually, these,
# Nearest to than: but, much, or, mmorpgs, sunda, resembling, migratory, predicate,
# Nearest to zero: five, seven, eight, four, six, three, nine, u,
# Nearest to so: before, too, impacting, thus, insecure, argued, envelope, keefe,
# Nearest to had: has, have, having, was, were, became, led, neoplatonic,
# Nearest to while: although, when, before, contaminants, though, after, and, including,
# Nearest to of: lofty, including, zhang, almagest, abortive, scat, wolfenstein, although,
# Nearest to used: known, referred, described, found, held, seen, responsible, required,
# Nearest to some: many, several, most, various, both, any, these, all,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to other: various, different, newsstand, many, eschewed, several, ralf, others,
# Nearest to known: used, referred, defined, regarded, such, seen, called, described,
# Nearest to into: through, from, xie, across, vertebra, comprise, charlatans, velar,
# Average loss at step 42000: 2.950550
# Average loss at step 44000: 2.958677
# Average loss at step 46000: 2.907392
# Average loss at step 48000: 2.867876
# Average loss at step 50000: 2.846658
# Nearest to when: before, if, while, after, where, grande, because, until,
# Nearest to american: british, italian, german, irish, french, edd, english, beehive,
# Nearest to more: less, most, very, rather, fewer, worse, quite, allotment,
# Nearest to which: that, what, this, usually, also, often, who, actually,
# Nearest to than: or, much, and, mmorpgs, resembling, sasl, jannaeus, chileans,
# Nearest to zero: seven, five, eight, four, six, nine, three, two,
# Nearest to so: before, thus, too, impacting, later, adjoint, maradona, resistances,
# Nearest to had: has, have, having, was, were, since, attempted, took,
# Nearest to while: although, before, when, contaminants, though, after, but, during,
# Nearest to of: abortive, during, from, in, lycos, almagest, cva, including,
# Nearest to used: referred, known, described, sold, found, held, designed, responsible,
# Nearest to some: many, several, these, any, most, certain, all, various,
# Nearest to five: six, seven, eight, four, three, nine, zero, two,
# Nearest to other: various, different, others, ob, older, severly, scanty, phonetic,
# Nearest to known: used, defined, regarded, such, referred, seen, available, possible,
# Nearest to into: through, from, across, around, xie, charlatans, asn, comprise,
# Average loss at step 52000: 2.891756
# Average loss at step 54000: 2.866942
# Average loss at step 56000: 2.862173
# Average loss at step 58000: 2.755363
# Average loss at step 60000: 2.839545
# Nearest to when: if, where, before, while, after, although, until, during,
# Nearest to american: german, italian, british, french, english, irish, australian, russian,
# Nearest to more: less, most, rather, very, larger, relatively, smaller, fewer,
# Nearest to which: that, also, this, what, who, usually, these, hogg,
# Nearest to than: or, but, like, casually, chileans, resembling, filmfare, glycosylation,
# Nearest to zero: five, seven, six, nine, three, four, eight, two,
# Nearest to so: too, impacting, sometimes, before, batll, myself, thus, oup,
# Nearest to had: has, have, was, having, were, wanted, already, never,
# Nearest to while: although, when, before, however, though, after, but, contaminants,
# Nearest to of: lofty, including, although, intents, wolfenstein, include, during, lycos,
# Nearest to used: described, referred, known, seen, defined, held, found, considered,
# Nearest to some: many, several, any, most, certain, xun, these, lemur,
# Nearest to five: seven, six, four, eight, nine, three, zero, two,
# Nearest to other: various, older, others, several, different, intergalactic, eschewed, phonetic,
# Nearest to known: used, defined, regarded, seen, such, described, referred, possible,
# Nearest to into: through, across, from, around, under, asn, replaces, between,
# Average loss at step 62000: 2.831699
# Average loss at step 64000: 2.779395
# Average loss at step 66000: 2.762984
# Average loss at step 68000: 2.714479
# Average loss at step 70000: 2.782906
# Nearest to when: if, before, after, while, where, although, though, thus,
# Nearest to american: australian, italian, british, canadian, irish, german, japanese, english,
# Nearest to more: less, most, larger, fewer, very, quite, rather, relatively,
# Nearest to which: that, this, also, usually, what, lechuck, actually, who,
# Nearest to than: much, or, resembling, sunda, mmorpgs, casually, commedia, yoga,
# Nearest to zero: six, five, eight, seven, nine, three, four, two,
# Nearest to so: too, thus, sometimes, before, sparrow, impacting, diminution, batll,
# Nearest to had: has, have, having, was, attempted, were, bendix, wanted,
# Nearest to while: although, when, before, however, after, during, though, began,
# Nearest to of: in, including, lofty, weighing, for, lakoff, alois, wolfenstein,
# Nearest to used: referred, applied, found, described, seen, available, defined, sold,
# Nearest to some: many, several, these, certain, any, numerous, various, this,
# Nearest to five: seven, six, nine, eight, three, four, two, zero,
# Nearest to other: various, older, naples, individual, fewer, many, several, newsstand,
# Nearest to known: such, regarded, defined, used, described, called, possible, referred,
# Nearest to into: through, from, under, across, via, suspending, around, within,
# Average loss at step 72000: 2.795111
# Average loss at step 74000: 2.643372
# Average loss at step 76000: 2.798840
# Average loss at step 78000: 2.824144
# Average loss at step 80000: 2.781075
# Nearest to when: before, after, if, while, although, during, though, where,
# Nearest to american: italian, irish, australian, german, british, african, canadian, japanese,
# Nearest to more: less, very, most, quite, relatively, larger, rather, smaller,
# Nearest to which: that, this, what, usually, these, also, lechuck, instead,
# Nearest to than: much, or, resembling, casually, even, mmorpgs, yoga, implicate,
# Nearest to zero: five, six, eight, seven, four, nine, three, two,
# Nearest to so: too, thus, sometimes, impacting, diminution, batll, farther, deadites,
# Nearest to had: has, have, having, was, were, saw, bendix, wanted,
# Nearest to while: although, when, before, after, though, began, jozef, contaminants,
# Nearest to of: in, including, and, institut, during, maternal, at, concerning,
# Nearest to used: known, described, referred, designed, seen, applied, defined, sold,
# Nearest to some: many, several, certain, these, any, both, numerous, all,
# Nearest to five: six, eight, seven, four, nine, three, zero, two,
# Nearest to other: various, fewer, ralf, older, many, individual, severly, agility,
# Nearest to known: used, regarded, referred, defined, possible, called, seen, described,
# Nearest to into: through, from, phylum, down, across, suspending, within, beyond,
# Average loss at step 82000: 2.665653
# Average loss at step 84000: 2.776476
# Average loss at step 86000: 2.733763
# Average loss at step 88000: 2.750323
# Average loss at step 90000: 2.734871
# Nearest to when: if, before, after, while, where, though, thus, unless,
# Nearest to american: italian, australian, british, african, irish, german, french, indian,
# Nearest to more: less, most, quite, very, fewer, relatively, larger, rather,
# Nearest to which: that, this, what, also, who, actually, lechuck, typically,
# Nearest to than: or, resembling, mmorpgs, much, but, casually, sunda, cgpm,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to so: too, thus, batll, sometimes, emf, impacting, farther, sparrow,
# Nearest to had: has, have, was, having, were, wanted, attempted, codebase,
# Nearest to while: although, though, when, however, before, after, began, jozef,
# Nearest to of: including, concerning, despite, lofty, for, wolfenstein, zhang, includes,
# Nearest to used: described, known, seen, referred, applied, found, designed, defined,
# Nearest to some: many, several, most, certain, numerous, any, both, various,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to other: various, older, ralf, agility, different, naples, invisibly, individual,
# Nearest to known: used, regarded, called, defined, such, described, possible, seen,
# Nearest to into: through, from, within, beyond, down, comprise, across, onto,
# Average loss at step 92000: 2.677990
# Average loss at step 94000: 2.727046
# Average loss at step 96000: 2.703262
# Average loss at step 98000: 2.366102
# Average loss at step 100000: 2.399940
# Nearest to when: if, before, while, after, though, unless, where, thus,
# Nearest to american: canadian, italian, english, australian, british, german, swiss, russian,
# Nearest to more: less, most, quite, very, fewer, rather, longer, larger,
# Nearest to which: what, that, this, also, actually, hogg, who, whom,
# Nearest to than: or, resembling, sunda, much, yoga, cgpm, least, mmorpgs,
# Nearest to zero: five, six, seven, eight, four, nine, three, two,
# Nearest to so: too, thus, sometimes, before, emf, once, sparrow, ye,
# Nearest to had: has, have, having, was, were, saw, ve, wanted,
# Nearest to while: although, when, though, began, before, however, after, whereas,
# Nearest to of: in, despite, lakoff, pretensions, including, intents, simultaneity, amore,
# Nearest to used: known, referred, described, designed, employed, applied, seen, found,
# Nearest to some: many, several, certain, any, numerous, these, various, most,
# Nearest to five: four, seven, six, eight, nine, three, zero, two,
# Nearest to other: others, various, ralf, individual, older, agility, inverses, attendants,
# Nearest to known: used, regarded, defined, such, available, described, seen, possible,
# Nearest to into: through, down, beyond, comprise, from, within, under, replaces,
